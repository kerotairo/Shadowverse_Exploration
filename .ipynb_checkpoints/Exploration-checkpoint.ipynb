# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
cards = pd.read_csv("cards.csv")
cards.drop(cards.columns[0], axis=1, inplace=True)
cards.drop(["cv","tokens"],axis=1, inplace=True)

# %%
l_char_type = {"1" : "Follower",
               "2" : "Amulet",
               "3" : "Countdown Amulet",
               "4" : "Spell"
              }

l_card_set = {"10000" : "Basic",
              "10001" : "Standard",
              "10002" : "Darkness Evolved",
              "10003" : "Rise of Bahamut",
              "10004" = "Tempest of the Gods",
              "10005" : "Wonderland Dreams",
              "10006" : "Starforged Legends",
              "10007" : "Chronogenesis",
              "10008" : "Dawnbreak, Nightedge",
              "10009" = "Brigade of the Sky",
              "10010" : "Omen of the Ten",
              "10011" = "Altersphere",
              "90000" : "Match only"
             }

l_clan = {"0" : "Neutral"
          "1" : "Forestcraft",
          "2" : "Swordcraft",
          "3" : "Runecraft",
          "4" : "Dragoncraft"
          "5" : "Shadowcraft",
          "6" : "Bloodcraft",
          "7" : "Havecraft",
          "8" : "Portalcraft"
         }

# %%
cards.head()
# Out:
#    atk  base_card_id    card_id              card_name  card_set_id  \
# 0    1     900111020  900111020             Fairy Wisp        90000
# 1    0     110124010  110124010  Mark of the Unkilling        10010
# 2    0     900144020  900144020  Blessings of Creation        90000
# 3    0     900144030  900144030        Wrath of Nature        90000
# 4    2     900231030  900231030     Evyn, Novice Agent        90000
#
#    char_type  clan copyright  cost  \
# 0          1     1       NaN     0
# 1          4     1       NaN     0
# 2          4     1       NaN     0
# 3          4     1       NaN     0
# 4          1     2       NaN     0
#
#                                          description  evo_atk  \
# 0  Gliding upon the wind, as if to illuminate the...        3
# 1  Burned by tears or torn by screams, you must b...        0
# 2  The noble shimmer of life for you, noble one. ...        0
# 3  The noble shimmer of life must not be defiled ...        0
# 4  Countless traps and snares, and all eyes on th...        2
#
#                                      evo_description  evo_life  \
# 0  Gliding upon the wind, gently floating as if w...         3
# 1                                                NaN         0
# 2                                                NaN         0
# 3                                                NaN         0
# 4  I can still turn this around! I just gotta sta...         4
#
#                                       evo_skill_disc  foil_card_id  \
# 0                                                NaN     900111021
# 1                                                NaN     110124011
# 2                                                NaN     900144021
# 3                                                NaN     900144031
# 4  Storm.<br>Evolve: Deal 2 damage to an enemy fo...     900231031
#
#    format_type  get_red_ether  is_foil  life  normal_card_id  \
# 0            1              0        0     1       900111020
# 1            1             50        0     0       110124010
# 2            1              0        0     0       900144020
# 3            1              0        0     0       900144030
# 4            1              0        0     2       900231030
#
#                                   org_evo_skill_disc  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [b]Storm[/b][b].[/b]<br>[b]Evolve[/b][b]:[/b] ...
#
#                                       org_skill_disc  rarity  \
# 0  [b]Fanfare[/b][b]:[/b] Banish this follower if...       1
# 1  Banish an enemy follower with 0 attack or less...       2
# 2  Draw 2 cards.<br>[b]Enhance[/b] [b](2)[/b][b]:...       4
# 3  Give an allied follower +1/+0 and [b]Rush[/b]....       4
# 4                                                NaN       3
#
#    restricted_count                               skill  \
# 0                 3                              banish
# 1                 3      banish,pp_fixeduse,banish,draw
# 2                 3  draw,pp_fixeduse,play_count_change
# 3                 3      powerup,rush,pp_fixeduse,quick
# 4                 3                  none//quick,damage
#
#                                           skill_disc  \
# 0  Fanfare: Banish this follower if at least 2 ot...
# 1  Banish an enemy follower with 0 attack or less...
# 2  Draw 2 cards.<br>Enhance (2): Add 2 to the num...
# 3  Give an allied follower +1/+0 and Rush.<br>Enh...
# 4                                                NaN
#
#                          skill_option tribe_name  use_red_ether
# 0                                none          -              0
# 1           none,fixeduse=6,none,none          -            200
# 2         none,fixeduse=2,add_count=2          -              0
# 3  add_offense=1,none,fixeduse=4,none          -              0
# 4                 none//none,damage=2    Officer              0

# %%
cards.describe(include="all")
# Out:
#                 atk  base_card_id       card_id card_name   card_set_id  \
# count   1840.000000  1.840000e+03  1.840000e+03      1840   1840.000000
# unique          NaN           NaN           NaN      1789           NaN
# top             NaN           NaN           NaN  Cerberus           NaN
# freq            NaN           NaN           NaN         3           NaN
# mean       2.263043  2.142800e+08  2.320066e+08       NaN  22341.250543
# std        2.070099  2.734279e+08  2.850912e+08       NaN  28431.661038
# min        0.000000  1.000110e+08  1.000110e+08       NaN  10000.000000
# 25%        0.000000  1.021310e+08  1.023210e+08       NaN  10002.000000
# 50%        2.000000  1.063225e+08  1.066210e+08       NaN  10006.000000
# 75%        4.000000  1.102158e+08  1.105410e+08       NaN  10010.000000
# max       20.000000  9.008420e+08  9.008420e+08       NaN  90000.000000
#
#           char_type         clan                   copyright         cost  \
# count   1840.000000  1840.000000                           7  1840.000000
# unique          NaN          NaN                           1          NaN
# top             NaN          NaN  ©TYPE-MOON・ufotable・FSNPC           NaN
# freq            NaN          NaN                           7          NaN
# mean       1.707065     3.910326                         NaN     3.984783
# std        1.197947     2.474251                         NaN     2.274235
# min        1.000000     0.000000                         NaN     0.000000
# 25%        1.000000     2.000000                         NaN     2.000000
# 50%        1.000000     4.000000                         NaN     4.000000
# 75%        2.000000     6.000000                         NaN     5.000000
# max        4.000000     8.000000                         NaN    20.000000
#
#                                               description      evo_atk  \
# count                                                1840  1840.000000
# unique                                               1811          NaN
# top     From this day forth, our order will be known a...          NaN
# freq                                                    3          NaN
# mean                                                  NaN     3.632609
# std                                                   NaN     2.741703
# min                                                   NaN     0.000000
# 25%                                                   NaN     0.000000
# 50%                                                   NaN     4.000000
# 75%                                                   NaN     5.000000
# max                                                   NaN    22.000000
#
#                                           evo_description     evo_life  \
# count                                                1326  1840.000000
# unique                                               1298          NaN
# top     "Woof! Are you going to the surface?" "Woof! A...          NaN
# freq                                                    3          NaN
# mean                                                  NaN     3.925543
# std                                                   NaN     2.938633
# min                                                   NaN     0.000000
# 25%                                                   NaN     0.000000
# 50%                                                   NaN     4.000000
# 75%                                                   NaN     6.000000
# max                                                   NaN    22.000000
#
#                        evo_skill_disc  foil_card_id  format_type  \
# count                             787  1.840000e+03  1840.000000
# unique                            481           NaN          NaN
# top     (Same as the unevolved form.)           NaN          NaN
# freq                              104           NaN          NaN
# mean                              NaN  2.320066e+08     0.513587
# std                               NaN  2.850912e+08     0.499951
# min                               NaN  1.000110e+08     0.000000
# 25%                               NaN  1.023210e+08     0.000000
# 50%                               NaN  1.066210e+08     1.000000
# 75%                               NaN  1.105410e+08     1.000000
# max                               NaN  9.008420e+08     1.000000
#
#         get_red_ether  is_foil         life  normal_card_id  \
# count     1840.000000   1840.0  1840.000000    1.840000e+03
# unique            NaN      NaN          NaN             NaN
# top               NaN      NaN          NaN             NaN
# freq              NaN      NaN          NaN             NaN
# mean       179.989130      0.0     2.562500    2.320066e+08
# std        318.029037      0.0     2.260473    2.850912e+08
# min          0.000000      0.0     0.000000    1.000110e+08
# 25%         10.000000      0.0     0.000000    1.023210e+08
# 50%         50.000000      0.0     2.000000    1.066210e+08
# 75%        250.000000      0.0     4.000000    1.105410e+08
# max       1000.000000      0.0    20.000000    9.008420e+08
#
#                    org_evo_skill_disc       org_skill_disc       rarity  \
# count                             787                 1731  1840.000000
# unique                            486                 1534          NaN
# top     (Same as the unevolved form.)  [b]Ward[/b][b].[/b]          NaN
# freq                              104                   25          NaN
# mean                              NaN                  NaN     2.200543
# std                               NaN                  NaN     1.100941
# min                               NaN                  NaN     1.000000
# 25%                               NaN                  NaN     1.000000
# 50%                               NaN                  NaN     2.000000
# 75%                               NaN                  NaN     3.000000
# max                               NaN                  NaN     4.000000
#
#         restricted_count   skill skill_disc skill_option tribe_name  \
# count        1840.000000    1840       1731         1840       1840
# unique               NaN     738       1528          988          7
# top                  NaN  damage      Ward.         none          -
# freq                 NaN     103         27          286       1604
# mean            2.994565     NaN        NaN          NaN        NaN
# std             0.104144     NaN        NaN          NaN        NaN
# min             1.000000     NaN        NaN          NaN        NaN
# 25%             3.000000     NaN        NaN          NaN        NaN
# 50%             3.000000     NaN        NaN          NaN        NaN
# 75%             3.000000     NaN        NaN          NaN        NaN
# max             3.000000     NaN        NaN          NaN        NaN
#
#         use_red_ether
# count     1840.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean       605.081522
# std       1084.606059
# min          0.000000
# 25%         50.000000
# 50%        200.000000
# 75%        800.000000
# max       3500.000000

# %%
cards[cards["copyright"].notnull()]
# Out:
#       atk  base_card_id    card_id         card_name  card_set_id  char_type  \
# 37      0     106114010  702114010  Airbound Barrage        70004          4
# 277     2     106221010  702221010            Lancer        70004          1
# 485     0     106624010  702624010   Snarling Chains        70004          4
# 733     0     106324010  702324010     Concentration        70004          4
# 774     0     106434010  702434010     Avowed Strike        70004          4
# 1324    3     106511010  702511010       Saber Alter        70004          1
# 1376    4     106721030  702721010         Berserker        70004          1
#
#       clan                   copyright  cost  \
# 37       1  ©TYPE-MOON・ufotable・FSNPC      1
# 277      2  ©TYPE-MOON・ufotable・FSNPC      2
# 485      6  ©TYPE-MOON・ufotable・FSNPC      2
# 733      3  ©TYPE-MOON・ufotable・FSNPC      3
# 774      4  ©TYPE-MOON・ufotable・FSNPC      3
# 1324     5  ©TYPE-MOON・ufotable・FSNPC      5
# 1376     7  ©TYPE-MOON・ufotable・FSNPC      5
#
#                                             description  evo_atk  \
# 37             I am the bone of my sword, Caladbolg II.        0
# 277   "They say that only the swiftest heroes are ch...        4
# 485   I'll start by plucking out those eyes that wer...        0
# 733   This is the most important fight, so I must pu...        0
# 774   Henceforth, my sword will be at your side. Hen...        0
# 1324  You know you cannot win, yet you persist... In...        5
# 1376  "I finally understand. You've been protecting ...        4
#
#                                         evo_description  evo_life  \
# 37                                                  NaN         0
# 277   "It strikes for the heart, and its aim is impe...         3
# 485                                                 NaN         0
# 733                                                 NaN         0
# 774                                                 NaN         0
# 1324  "Thank you, Saber... You've saved me more time...         7
# 1376  "He won't lose. Berserker won't lose to the li...         3
#
#                                          evo_skill_disc  foil_card_id  \
# 37                                                  NaN     702114011
# 277   Rush.<br><br>(This card will be treated as Cuh...     702221011
# 485                                                 NaN     702624011
# 733                                                 NaN     702324011
# 774                                                 NaN     702434011
# 1324  Ward.<br>At the end of your turn, perform Necr...     702511011
# 1376  Can attack 2 times per turn.<br>Whenever 2 dam...     702721011
#
#       format_type  get_red_ether  is_foil  life  normal_card_id  \
# 37              0              0        0     0       702114010
# 277             0              0        0     1       702221010
# 485             0              0        0     0       702624010
# 733             0              0        0     0       702324010
# 774             0              0        0     0       702434010
# 1324            0              0        0     5       702511010
# 1376            0              0        0     3       702721010
#
#                                      org_evo_skill_disc  \
# 37                                                  NaN
# 277   [b]Rush[/b][b].[/b]<br><br>(This card will be ...
# 485                                                 NaN
# 733                                                 NaN
# 774                                                 NaN
# 1324  [b]Ward[/b][b].[/b]<br>At the end of your turn...
# 1376  Can attack 2 times per turn.<br>Whenever 2 dam...
#
#                                          org_skill_disc  rarity  \
# 37    Return an allied follower or an amulet to your...       1
# 277   [b]Rush[/b][b].[/b]<br>[b]Fanfare[/b][b]:[/b] ...       2
# 485   Deal 1 damage to both leaders.<br>Then deal 3 ...       2
# 733   Draw 2 cards.<br>[b]Earth Rite[/b][b]:[/b] Dra...       2
# 774   Deal X damage to an enemy follower. X equals t...       3
# 1324  [b]Ward[/b][b].[/b]<br>At the end of your turn...       1
# 1376  Whenever 2 damage or less is dealt to this fol...       2
#
#       restricted_count                                     skill  \
# 37                   3                        return_card,damage
# 277                  3            pp_fixeduse,rush,killer,shield
# 485                  3                             damage,damage
# 733                  3                            draw,draw,heal
# 774                  3            pp_fixeduse,draw,damage,damage
# 1324                 3                         none,guard,damage
# 1376                 3  damage_cut,powerup//powerup,attack_count
#
#                                              skill_disc  \
# 37    Return an allied follower or an amulet to your...
# 277   Rush.<br>Fanfare: Enhance (6) - Gain Bane unti...
# 485   Deal 1 damage to both leaders.<br>Then deal 3 ...
# 733   Draw 2 cards.<br>Earth Rite: Draw 3 cards inst...
# 774   Deal X damage to an enemy follower. X equals t...
# 1324  Ward.<br>At the end of your turn, perform Necr...
# 1376  Whenever 2 damage or less is dealt to this fol...
#
#                                            skill_option  tokens tribe_name  \
# 37                                        none,damage=3     NaN          -
# 277                           fixeduse=6,none,none,none     NaN    Officer
# 485                                   damage=1,damage=3     NaN          -
# 733                                 none,none,healing=1     NaN          -
# 774   fixeduse=7,none,damage=2*{me.hand.clan=dragon....     NaN          -
# 1324                                 none,none,damage=2     NaN          -
# 1376  cut_clipping=0&cut_clipping_range=2,add_life=1...     NaN          -
#
#       use_red_ether
# 37                0
# 277               0
# 485               0
# 733               0
# 774               0
# 1324              0
# 1376              0

# %%
alt_cards = cards[cards["base_card_id"] != cards["card_id"]]
base_cards = cards[cards["base_card_id"] == cards["card_id"]]

# %%
base_cards = base_cards.drop(["base_card_id","foil_card_id","normal_card_id"], axis=1)
base_cards.head()
# Out:
#    atk    card_id              card_name  card_set_id  char_type  clan  \
# 0    1  900111020             Fairy Wisp        90000          1     1
# 1    0  110124010  Mark of the Unkilling        10010          4     1
# 2    0  900144020  Blessings of Creation        90000          4     1
# 3    0  900144030        Wrath of Nature        90000          4     1
# 4    2  900231030     Evyn, Novice Agent        90000          1     2
#
#   copyright  cost                                        description  evo_atk  \
# 0       NaN     0  Gliding upon the wind, as if to illuminate the...        3
# 1       NaN     0  Burned by tears or torn by screams, you must b...        0
# 2       NaN     0  The noble shimmer of life for you, noble one. ...        0
# 3       NaN     0  The noble shimmer of life must not be defiled ...        0
# 4       NaN     0  Countless traps and snares, and all eyes on th...        2
#
#                                      evo_description  evo_life  \
# 0  Gliding upon the wind, gently floating as if w...         3
# 1                                                NaN         0
# 2                                                NaN         0
# 3                                                NaN         0
# 4  I can still turn this around! I just gotta sta...         4
#
#                                       evo_skill_disc  format_type  \
# 0                                                NaN            1
# 1                                                NaN            1
# 2                                                NaN            1
# 3                                                NaN            1
# 4  Storm.<br>Evolve: Deal 2 damage to an enemy fo...            1
#
#    get_red_ether  is_foil  life  \
# 0              0        0     1
# 1             50        0     0
# 2              0        0     0
# 3              0        0     0
# 4              0        0     2
#
#                                   org_evo_skill_disc  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [b]Storm[/b][b].[/b]<br>[b]Evolve[/b][b]:[/b] ...
#
#                                       org_skill_disc  rarity  \
# 0  [b]Fanfare[/b][b]:[/b] Banish this follower if...       1
# 1  Banish an enemy follower with 0 attack or less...       2
# 2  Draw 2 cards.<br>[b]Enhance[/b] [b](2)[/b][b]:...       4
# 3  Give an allied follower +1/+0 and [b]Rush[/b]....       4
# 4                                                NaN       3
#
#    restricted_count                               skill  \
# 0                 3                              banish
# 1                 3      banish,pp_fixeduse,banish,draw
# 2                 3  draw,pp_fixeduse,play_count_change
# 3                 3      powerup,rush,pp_fixeduse,quick
# 4                 3                  none//quick,damage
#
#                                           skill_disc  \
# 0  Fanfare: Banish this follower if at least 2 ot...
# 1  Banish an enemy follower with 0 attack or less...
# 2  Draw 2 cards.<br>Enhance (2): Add 2 to the num...
# 3  Give an allied follower +1/+0 and Rush.<br>Enh...
# 4                                                NaN
#
#                          skill_option tribe_name  use_red_ether
# 0                                none          -              0
# 1           none,fixeduse=6,none,none          -            200
# 2         none,fixeduse=2,add_count=2          -              0
# 3  add_offense=1,none,fixeduse=4,none          -              0
# 4                 none//none,damage=2    Officer              0

# %%
base_cards.card_set_id.unique()
# Out:
# array([90000, 10010, 10008, 10009, 10007, 10000, 10004, 10001, 10006,
#        10003, 10011, 10002, 10005], dtype=int64)
